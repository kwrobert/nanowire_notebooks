# %%
import numpy as np
import matplotlib.pyplot as plt
from nanowire.optics.simulate import Simulator
from nanowire.optics.postprocess import Simulation
from nanowire.optics.utils.utils import setup_sim
from nanowire.optics.utils.config import Config
import scipy.constants as consts
import scipy.integrate as intg
# %load_ext autoreload
# %autoreload 2

# %%
conf = Config('../vacuum_test_conf.yml')
sim = Simulator(conf)
sim = setup_sim(sim)

# %%
sim.get_fluxes()
sim.get_field()

# %%
sim_proc = Simulation(simulator=sim)

# %%
sim_proc.fixed_line('normE', 'z', 31, 31)
sim_proc.fixed_line('normEsquared', 'z', 31, 31)
sim_proc.fixed_line('normH', 'z', 31, 31)
sim_proc.fixed_line('normHsquared', 'z', 31, 31)

# %%
sim_proc.fixed_line('Ex', 'z', 31, 31)
sim_proc.fixed_line('Ey', 'z', 31, 31)
sim_proc.fixed_line('Ez', 'z', 31, 31)
sim_proc.fixed_line('Hx', 'z', 31, 31)
sim_proc.fixed_line('Hy', 'z', 31, 31)
sim_proc.fixed_line('Hz', 'z', 31, 31)

# %%
sim_proc.data['fluxes']
# Out:
# {'Air': ((3.9999999999999996+0j), 0j), 'Air_bottom': ((4+0j), 0j)}

# %%
sim_proc.absorption_per_layer()
# Out:
# INFO:nanowire.optics.postprocess:Layer absorption dict: {'Air': [-2.220446049250313e-16, None, None]}
# Layer: Air
# Flux Method Absorbed: -2.220446049250313e-16
# (250, 62, 62)
# {'Air': [-2.220446049250313e-16, None, None]}
# {'Air': [-2.220446049250313e-16, None, None]}

# %%
plt.figure()
plt.plot(np.absolute(sim_proc.data['Ex'][:, 31, 31]))
plt.show()
